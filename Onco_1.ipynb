# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshDumo/Oncology-StreamLit/blob/main/Onco_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Colorectal histopathology**
# ## Classification of textures
#
# Histopathologists study and diagnose diseases in tissues by examining the tissues under a microscope [1]. This technique is particularly useful in diagnosing cancer, where tissue obtained from suspicious lumps can be analyzed and classified if cancerous. The preparation of tissues for imaging is an involved process, but it can be summarized broadly into three steps: fixation, staining, and mounting [2,3]. Fixation is done to keep the tissue as life-like as possible, by preserving it in chemical agents like fomaldehyde. Staining enhances the visualization of organelles and membranes. The tissue is then mounted on glass slides for support so they can be imaged.  Once the preparation is done the tissue can be imaged under a microscope and digitized.
#
# Here we develop a system that uses AI/ML based image classification to classify tissue from digital images from colorectal histopathology. Colorectal images are obtained from ref [4] which is provided on Tensorflow Datasets catalog. The images are used to train a CNN network using Tensorflow. The resulting model is used to classify the images into one of 8 classes: 'Tumor', 'Stroma', 'Complex', 'Lympho', 'Debris','Mucosa', 'Adipose', and 'Empty'.
#
# In addition, we use Integrated Gradients to provide a measure of explainability for the model. This is important for these 'mission critical' applications. We note also that, especially for medical applications, the effective approach is what is now being called "AI + X", where AI is not a replacement of expertise, but rather an augmentation.

# %% [markdown]
# ## Code
# We begin by importing the essential libraries

# %%
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

import pandas as pd
import numpy as np

import seaborn as sns

from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix

print("\u2022 Using TensorFlow Version:", tf.__version__)
# Out:
# • Using TensorFlow Version: 2.4.1

# %% [markdown]
# ### ETL
#
# I use the the Extract, Transform and Load (ETL) approach to obtain the data and preprocess it for training.

# %%
# EXTRACT

test_ds = tfds.load(name="colorectal_histology", 
                   split="train[0%:10%]",
                   shuffle_files=True,
                   as_supervised=True)

val_ds = tfds.load(name="colorectal_histology", 
                   split="train[10%:30%]",
                   shuffle_files=True,
                   as_supervised=True)

train_ds = tfds.load(name="colorectal_histology", 
                     split="train[-70%:]", 
                     shuffle_files=True, 
                     as_supervised=True)

for data in train_ds.take(1):
    image = data[0].numpy().squeeze()
    label = data[1].numpy()
    
    print("Label: {}".format(label))
    plt.imshow(image, cmap=plt.cm.binary)
    plt.show()
# Out:
# Downloading and preparing dataset colorectal_histology/2.0.0 (download: 246.14 MiB, generated: Unknown size, total: 246.14 MiB) to /root/tensorflow_datasets/colorectal_histology/2.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Extraction completed...', max=1.0, styl…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/colorectal_histology/2.0.0.incompleteRP185W/colorectal_histology-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=5000.0), HTML(value='')))
# Dataset colorectal_histology downloaded and prepared to /root/tensorflow_datasets/colorectal_histology/2.0.0. Subsequent calls will reuse this data.
# Label: 6

# %%
# Extract labels
tester = test_ds.take(1)
img_1 = []
lab_1 = 0
for example in tester:  
  img_1 = example[0]
  lab_1 = example[1]
img_1.shape
lab_1
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=5>

# %%
def normalize_img(image, label):
  """Normalizes images: `uint8` -> `float32`."""
  return tf.cast(image, tf.float32) / 255., label

# %%
tds = train_ds.as_numpy_iterator()
labs = []
for el in tds:
  labs.append(el[1])

lab_cnt = []
for i in range(0,8):
  lab_cnt.append(labs.count(i))
lab_cnt
lab_list = ['Tumor', 'Stroma','Complex', 'Lympho','Debris','Mucosa','Adipose','Empty']

# %%
plt.pie(lab_cnt, labels=['Tumor', 'Stroma','Complex', 'Lympho','Debris','Mucosa','Adipose','Empty'], startangle=180, 
        autopct='%1.1f', shadow=True)
plt.figure(figsize=(16,16))
plt.show()

# %%
test_lb = test_ds.as_numpy_iterator()
test_labels = []
for tlb in test_lb:
  test_labels.append(tlb[1])

# %% [markdown]
# #### Transform
# Normalize the images to float32 between 0 - 1. Then shuffle, batch, cache and prefetch.

# %%
train_ds = train_ds.map(normalize_img,
                        num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.cache().shuffle(1000).batch(128).prefetch(tf.data.AUTOTUNE)

# %%
val_ds = val_ds.map(normalize_img,
                    num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.batch(128).cache().prefetch(tf.data.AUTOTUNE)

# %%
test_ds = test_ds.map(normalize_img,
                    num_parallel_calls=tf.data.AUTOTUNE)
test_ds = test_ds.batch(128).cache().prefetch(tf.data.AUTOTUNE)

# %%
val_ds.enumerate()
# Out:
# <ZipDataset shapes: ((), ((None, 150, 150, 3), (None,))), types: (tf.int64, (tf.float32, tf.int64))>

# %% [markdown]
# ### Model
# We design a simple 2D Convolutional Neural Network to classify the textures.

# %%
kernel_size = (3,3)
pool_size= (2,2)

## Model 3
#zeroth_filters = 16
#first_filters = 64
#second_filters = 256
#third_filters = 1024

## Model 4
zeroth_filters = 16
first_filters = 64
second_filters = 256
third_filters = 1024

dropout_conv = 0.3
dropout_dense = 0.3


model = tf.keras.models.Sequential([
                                    layers.Conv2D(zeroth_filters, kernel_size, padding='same',activation = 'relu', input_shape = (150, 150, 3)),
                                    layers.MaxPooling2D(pool_size = pool_size),
                                    layers.Conv2D(first_filters, kernel_size, activation = 'relu'),
                                    layers.MaxPooling2D(pool_size = pool_size),
                                    layers.Conv2D(second_filters, kernel_size, activation ='relu'),
                                    layers.MaxPooling2D(pool_size = pool_size),
                                    layers.Conv2D(third_filters, kernel_size, activation ='relu'),
                                    layers.MaxPooling2D(pool_size = pool_size),
                                    
                                    layers.Flatten(),
                                    layers.Dense(256, activation = "relu"),
                                    layers.Dense(8, activation = "softmax")
                                    
])


model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 150, 150, 16)      448
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 73, 73, 64)        9280
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 34, 34, 256)       147712
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 17, 17, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 1024)      2360320
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 1024)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               12845312
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 15,365,128
# Trainable params: 15,365,128
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# %% [markdown]
# ### Training

# %%
filepath = "model5.h5"
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_sparse_categorical_accuracy', verbose=1, 
                             save_best_only=True, mode='max')

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_sparse_categorical_accuracy', factor=0.5, patience=2, 
                                   verbose=1, mode='max', min_lr=0.00001)
                              
                              
callbacks_list = [checkpoint, reduce_lr]

history = model.fit(train_ds, 
                    validation_data=val_ds,
                    epochs=40, verbose=1,
                   callbacks=callbacks_list)
# Out:
# Epoch 1/40
# 28/28 [==============================] - 6s 153ms/step - loss: 2.2493 - sparse_categorical_accuracy: 0.2141 - val_loss: 1.1508 - val_sparse_categorical_accuracy: 0.5040
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.50400, saving model to model5.h5
# Epoch 2/40
# 28/28 [==============================] - 4s 127ms/step - loss: 1.1178 - sparse_categorical_accuracy: 0.5568 - val_loss: 0.9534 - val_sparse_categorical_accuracy: 0.5530
#
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.50400 to 0.55300, saving model to model5.h5
# Epoch 3/40
# 28/28 [==============================] - 4s 128ms/step - loss: 0.8638 - sparse_categorical_accuracy: 0.6345 - val_loss: 0.7239 - val_sparse_categorical_accuracy: 0.7360
#
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.55300 to 0.73600, saving model to model5.h5
# Epoch 4/40
# 28/28 [==============================] - 4s 125ms/step - loss: 0.7373 - sparse_categorical_accuracy: 0.7159 - val_loss: 0.7965 - val_sparse_categorical_accuracy: 0.6170
#
# Epoch 00004: val_sparse_categorical_accuracy did not improve from 0.73600
# Epoch 5/40
# 28/28 [==============================] - 4s 127ms/step - loss: 0.7500 - sparse_categorical_accuracy: 0.6831 - val_loss: 0.6533 - val_sparse_categorical_accuracy: 0.7700
#
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.73600 to 0.77000, saving model to model5.h5
# Epoch 6/40
# 28/28 [==============================] - 4s 126ms/step - loss: 0.6360 - sparse_categorical_accuracy: 0.7535 - val_loss: 0.7193 - val_sparse_categorical_accuracy: 0.7180
#
# Epoch 00006: val_sparse_categorical_accuracy did not improve from 0.77000
# Epoch 7/40
# 28/28 [==============================] - 4s 127ms/step - loss: 0.6632 - sparse_categorical_accuracy: 0.7474 - val_loss: 0.6515 - val_sparse_categorical_accuracy: 0.7710
#
# Epoch 00007: val_sparse_categorical_accuracy improved from 0.77000 to 0.77100, saving model to model5.h5
# Epoch 8/40
# 28/28 [==============================] - 4s 127ms/step - loss: 0.5544 - sparse_categorical_accuracy: 0.7873 - val_loss: 0.7605 - val_sparse_categorical_accuracy: 0.7200
#
# Epoch 00008: val_sparse_categorical_accuracy did not improve from 0.77100
# Epoch 9/40
# 28/28 [==============================] - 4s 129ms/step - loss: 0.5859 - sparse_categorical_accuracy: 0.7826 - val_loss: 0.6182 - val_sparse_categorical_accuracy: 0.7440
#
# Epoch 00009: val_sparse_categorical_accuracy did not improve from 0.77100
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 10/40
# 28/28 [==============================] - 4s 127ms/step - loss: 0.5124 - sparse_categorical_accuracy: 0.8050 - val_loss: 0.4946 - val_sparse_categorical_accuracy: 0.8070
#
# Epoch 00010: val_sparse_categorical_accuracy improved from 0.77100 to 0.80700, saving model to model5.h5
# Epoch 11/40
# 28/28 [==============================] - 4s 128ms/step - loss: 0.3973 - sparse_categorical_accuracy: 0.8540 - val_loss: 0.4802 - val_sparse_categorical_accuracy: 0.8200
#
# Epoch 00011: val_sparse_categorical_accuracy improved from 0.80700 to 0.82000, saving model to model5.h5
# Epoch 12/40
# 28/28 [==============================] - 4s 127ms/step - loss: 0.4239 - sparse_categorical_accuracy: 0.8364 - val_loss: 0.4497 - val_sparse_categorical_accuracy: 0.8250
#
# Epoch 00012: val_sparse_categorical_accuracy improved from 0.82000 to 0.82500, saving model to model5.h5
# Epoch 13/40
# 28/28 [==============================] - 4s 127ms/step - loss: 0.3732 - sparse_categorical_accuracy: 0.8693 - val_loss: 0.6705 - val_sparse_categorical_accuracy: 0.7380
#
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.82500
# Epoch 14/40
# 28/28 [==============================] - 4s 128ms/step - loss: 0.5345 - sparse_categorical_accuracy: 0.7729 - val_loss: 0.4824 - val_sparse_categorical_accuracy: 0.8220
#
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.82500
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 15/40
# 28/28 [==============================] - 4s 128ms/step - loss: 0.3572 - sparse_categorical_accuracy: 0.8735 - val_loss: 0.4925 - val_sparse_categorical_accuracy: 0.8110
#
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.82500
# Epoch 16/40
# 28/28 [==============================] - 4s 129ms/step - loss: 0.3693 - sparse_categorical_accuracy: 0.8642 - val_loss: 0.4597 - val_sparse_categorical_accuracy: 0.8280
#
# Epoch 00016: val_sparse_categorical_accuracy improved from 0.82500 to 0.82800, saving model to model5.h5
# Epoch 17/40
# 28/28 [==============================] - 4s 129ms/step - loss: 0.3292 - sparse_categorical_accuracy: 0.8753 - val_loss: 0.4389 - val_sparse_categorical_accuracy: 0.8510
#
# Epoch 00017: val_sparse_categorical_accuracy improved from 0.82800 to 0.85100, saving model to model5.h5
# Epoch 18/40
# 28/28 [==============================] - 4s 129ms/step - loss: 0.3073 - sparse_categorical_accuracy: 0.8935 - val_loss: 0.4507 - val_sparse_categorical_accuracy: 0.8400
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.85100
# Epoch 19/40
# 28/28 [==============================] - 4s 129ms/step - loss: 0.3072 - sparse_categorical_accuracy: 0.8797 - val_loss: 0.4646 - val_sparse_categorical_accuracy: 0.8450
#
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.85100
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 20/40
# 28/28 [==============================] - 4s 129ms/step - loss: 0.2807 - sparse_categorical_accuracy: 0.9017 - val_loss: 0.4292 - val_sparse_categorical_accuracy: 0.8540
#
# Epoch 00020: val_sparse_categorical_accuracy improved from 0.85100 to 0.85400, saving model to model5.h5
# Epoch 21/40
# 28/28 [==============================] - 4s 131ms/step - loss: 0.2641 - sparse_categorical_accuracy: 0.9085 - val_loss: 0.4316 - val_sparse_categorical_accuracy: 0.8510
#
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.85400
# Epoch 22/40
# 28/28 [==============================] - 4s 131ms/step - loss: 0.2681 - sparse_categorical_accuracy: 0.9090 - val_loss: 0.4476 - val_sparse_categorical_accuracy: 0.8480
#
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.85400
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 23/40
# 28/28 [==============================] - 4s 130ms/step - loss: 0.2510 - sparse_categorical_accuracy: 0.9173 - val_loss: 0.4284 - val_sparse_categorical_accuracy: 0.8570
#
# Epoch 00023: val_sparse_categorical_accuracy improved from 0.85400 to 0.85700, saving model to model5.h5
# Epoch 24/40
# 28/28 [==============================] - 4s 130ms/step - loss: 0.2559 - sparse_categorical_accuracy: 0.9086 - val_loss: 0.4315 - val_sparse_categorical_accuracy: 0.8550
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.85700
# Epoch 25/40
# 28/28 [==============================] - 4s 130ms/step - loss: 0.2430 - sparse_categorical_accuracy: 0.9133 - val_loss: 0.4351 - val_sparse_categorical_accuracy: 0.8580
#
# Epoch 00025: val_sparse_categorical_accuracy improved from 0.85700 to 0.85800, saving model to model5.h5
# Epoch 26/40
# 28/28 [==============================] - 4s 131ms/step - loss: 0.2482 - sparse_categorical_accuracy: 0.9192 - val_loss: 0.4296 - val_sparse_categorical_accuracy: 0.8570
#
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.85800
# Epoch 27/40
# 28/28 [==============================] - 4s 131ms/step - loss: 0.2346 - sparse_categorical_accuracy: 0.9253 - val_loss: 0.4281 - val_sparse_categorical_accuracy: 0.8540
#
# Epoch 00027: val_sparse_categorical_accuracy did not improve from 0.85800
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 28/40
# 28/28 [==============================] - 4s 132ms/step - loss: 0.2454 - sparse_categorical_accuracy: 0.9129 - val_loss: 0.4337 - val_sparse_categorical_accuracy: 0.8600
#
# Epoch 00028: val_sparse_categorical_accuracy improved from 0.85800 to 0.86000, saving model to model5.h5
# Epoch 29/40
# 28/28 [==============================] - 4s 138ms/step - loss: 0.2377 - sparse_categorical_accuracy: 0.9181 - val_loss: 0.4395 - val_sparse_categorical_accuracy: 0.8570
#
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.86000
# Epoch 30/40
# 28/28 [==============================] - 4s 132ms/step - loss: 0.2324 - sparse_categorical_accuracy: 0.9239 - val_loss: 0.4432 - val_sparse_categorical_accuracy: 0.8620
#
# Epoch 00030: val_sparse_categorical_accuracy improved from 0.86000 to 0.86200, saving model to model5.h5
# Epoch 31/40
# 28/28 [==============================] - 4s 132ms/step - loss: 0.2246 - sparse_categorical_accuracy: 0.9191 - val_loss: 0.4363 - val_sparse_categorical_accuracy: 0.8610
#
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.86200
# Epoch 32/40
# 28/28 [==============================] - 4s 133ms/step - loss: 0.2330 - sparse_categorical_accuracy: 0.9185 - val_loss: 0.4531 - val_sparse_categorical_accuracy: 0.8600
#
# Epoch 00032: val_sparse_categorical_accuracy did not improve from 0.86200
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 33/40
# 28/28 [==============================] - 4s 132ms/step - loss: 0.2339 - sparse_categorical_accuracy: 0.9172 - val_loss: 0.4446 - val_sparse_categorical_accuracy: 0.8590
#
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.86200
# Epoch 34/40
# 28/28 [==============================] - 4s 132ms/step - loss: 0.2336 - sparse_categorical_accuracy: 0.9198 - val_loss: 0.4439 - val_sparse_categorical_accuracy: 0.8600
#
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.86200
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 35/40
# 28/28 [==============================] - 4s 133ms/step - loss: 0.2192 - sparse_categorical_accuracy: 0.9274 - val_loss: 0.4382 - val_sparse_categorical_accuracy: 0.8630
#
# Epoch 00035: val_sparse_categorical_accuracy improved from 0.86200 to 0.86300, saving model to model5.h5
# Epoch 36/40
# 28/28 [==============================] - 4s 131ms/step - loss: 0.2265 - sparse_categorical_accuracy: 0.9194 - val_loss: 0.4398 - val_sparse_categorical_accuracy: 0.8610
#
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.86300
# Epoch 37/40
# 28/28 [==============================] - 4s 132ms/step - loss: 0.2153 - sparse_categorical_accuracy: 0.9271 - val_loss: 0.4389 - val_sparse_categorical_accuracy: 0.8580
#
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.86300
# Epoch 38/40
# 28/28 [==============================] - 4s 134ms/step - loss: 0.2266 - sparse_categorical_accuracy: 0.9249 - val_loss: 0.4424 - val_sparse_categorical_accuracy: 0.8600
#
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.86300
# Epoch 39/40
# 28/28 [==============================] - 4s 132ms/step - loss: 0.2269 - sparse_categorical_accuracy: 0.9245 - val_loss: 0.4405 - val_sparse_categorical_accuracy: 0.8620
#
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.86300
# Epoch 40/40
# 28/28 [==============================] - 4s 133ms/step - loss: 0.2166 - sparse_categorical_accuracy: 0.9271 - val_loss: 0.4416 - val_sparse_categorical_accuracy: 0.8630
#
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.86300

# %% [markdown]
# ### Evaluating the Model

# %%
val_loss, val_acc = model.evaluate(test_ds)
# Out:
# 4/4 [==============================] - 1s 152ms/step - loss: 0.4259 - sparse_categorical_accuracy: 0.8540

# %%
val_loss, val_acc
# Out:
# (0.42587873339653015, 0.8539999723434448)

# %%
acc = history.history['sparse_categorical_accuracy']
val_acc = history.history['val_sparse_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.figure()

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

# %%
predictions = model.predict(test_ds)

# %%
preds_ds = pd.DataFrame(predictions, columns=lab_list)
preds_ds.head()
# Out:
#       Tumor        Stroma  ...       Adipose         Empty
# 0  0.000211  4.826045e-01  ...  6.883481e-06  3.823944e-08
# 1  0.002542  1.796703e-02  ...  3.707902e-07  3.952829e-18
# 2  0.911673  8.722422e-13  ...  1.005480e-15  2.208694e-25
# 3  0.999982  1.481742e-17  ...  9.383582e-21  3.958307e-31
# 4  0.000001  4.486395e-06  ...  9.954307e-01  4.000720e-03
#
# [5 rows x 8 columns]

# %% [markdown]
# #### Confusion Matrix

# %%
from sklearn.metrics import roc_auc_score

cm = confusion_matrix(test_labels, predictions.argmax(axis=1))

# %%
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix');

# %% [markdown]
# ## Model Explainability using Integrated Gradients (IG)
#
# Integrated Gradients (IG) is a method for explaining the outputs of an AI model [5]. In this case, IG aims to explain the pixels that contributed to the classification of an image.
#
# IG has the formula
#
# $IntegratedGrads^{approx}_{i}(x)::=(x_{i}-x'_{i})\times\sum_{k=1}^{m}\frac{\overbrace{\partial F(\text{interpolated images})}^\text{compute gradients}}{\partial x_{i}} \times \frac{1}{m}$
#
# where:
# $F()$ = your model's prediction function
# $\frac{\partial{F}}{\partial{x_i}}$ = gradient (vector of partial derivatives $\partial$) of your model F's prediction function relative to each feature $x_i$

# %%
import pathlib
import PIL

#im_2 = PIL.Image.open("/content/10C74_CRC-Prim-HE-03.tif_Row_1651_Col_601.tif")
im_3 = tf.keras.preprocessing.image.load_img("/content/01Tumor.tif")
im_3 = tf.keras.preprocessing.image.img_to_array(im_3)
im_3 = tf.cast(im_3, tf.float32) / 255.

# %%
im_3_tensor = np.expand_dims(im_3,axis=0)
predictionz = model.predict(im_3_tensor)

sorted_preds, sorted_labels = (list(reversed(t)) for t in zip(*sorted(zip(predictionz[0], lab_list))))
fig_bar = plt.figure()
plt.barh(sorted_labels, sorted_preds)
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# ### Interpolated images
# I used a white image as the baseline as it appears to perform better in visualizing the interpretation. However it it possible to use a black, random or some other function as the baseline.

# %%
baseline_im = tf.ones(shape=(150,150,3))

# %%
plt.imshow(baseline_im)
plt.title("Baseline")
plt.axis('off')
plt.show()

# %%
m_steps=50
alphas = tf.linspace(start=0.0, stop=1.0, num=m_steps+1) # Generate m_steps intervals for integral_approximation() below.

# %%
def interpolate_images(baseline,
                       image,
                       alphas):
  alphas_x = alphas[:, tf.newaxis, tf.newaxis, tf.newaxis]
  baseline_x = tf.expand_dims(baseline, axis=0)
  input_x = tf.expand_dims(image, axis=0)
  delta = input_x - baseline_x
  images = baseline_x +  alphas_x * delta
  return images

# %%
interpolated_images = interpolate_images(
    baseline=baseline_im,
    image=im_3,
    alphas=alphas)

# %%
fig = plt.figure(figsize=(20, 20))

i = 0
for alpha, image in zip(alphas[0::10], interpolated_images[0::10]):
  i += 1
  plt.subplot(1, len(alphas[0::10]), i)
  plt.title(f'alpha: {alpha:.1f}')
  plt.imshow(image)
  plt.axis('off')

plt.tight_layout();

# %% [markdown]
# #### Gradients

# %%
def compute_gradients(images, target_class_idx):
  with tf.GradientTape() as tape:
    tape.watch(images)
    logits = model(images)
    probs = tf.nn.softmax(logits, axis=-1)[:, target_class_idx]
  return tape.gradient(probs, images)

# %%
path_gradients = compute_gradients(
    images=interpolated_images,
    target_class_idx=0)

# %%
pred = model(interpolated_images)
pred_proba = tf.nn.softmax(pred, axis=-1)[:, 0]

plt.figure(figsize=(10, 4))
ax1 = plt.subplot(1, 2, 1)
ax1.plot(alphas, pred_proba)
ax1.set_title('Target class predicted probability over alpha')
ax1.set_ylabel('model p(target class)')
ax1.set_xlabel('alpha')
ax1.set_ylim([0, 1])

ax2 = plt.subplot(1, 2, 2)
# Average across interpolation steps
average_grads = tf.reduce_mean(path_gradients, axis=[1, 2, 3])
# Normalize gradients to 0 to 1 scale. E.g. (x - min(x))/(max(x)-min(x))
average_grads_norm = (average_grads-tf.math.reduce_min(average_grads))/(tf.math.reduce_max(average_grads)-tf.reduce_min(average_grads))
ax2.plot(alphas, average_grads_norm)
ax2.set_title('Average pixel gradients (normalized) over alpha')
ax2.set_ylabel('Average pixel gradients')
ax2.set_xlabel('alpha')
ax2.set_ylim([0, 1]);

# %% [markdown]
# #### Integral Approximation
#
# Here the Trapezoid rule is used. Other approaches are also possible. The Simpson's rule maybe a better option.

# %%
def integral_approximation(gradients):
  # riemann_trapezoidal
  grads = (gradients[:-1] + gradients[1:]) / tf.constant(2.0)
  integrated_gradients = tf.math.reduce_mean(grads, axis=0)
  return integrated_gradients

# %%
ig = integral_approximation(
    gradients=path_gradients)

# %% [markdown]
# ### IG in full

# %%
@tf.function
def integrated_gradients(baseline,
                         image,
                         target_class_idx,
                         m_steps=50,
                         batch_size=32):
  # 1. Generate alphas.
  alphas = tf.linspace(start=0.0, stop=1.0, num=m_steps+1)

  # Initialize TensorArray outside loop to collect gradients.    
  gradient_batches = tf.TensorArray(tf.float32, size=m_steps+1)

  # Iterate alphas range and batch computation for speed, memory efficiency, and scaling to larger m_steps.
  for alpha in tf.range(0, len(alphas), batch_size):
    from_ = alpha
    to = tf.minimum(from_ + batch_size, len(alphas))
    alpha_batch = alphas[from_:to]

    # 2. Generate interpolated inputs between baseline and input.
    interpolated_path_input_batch = interpolate_images(baseline=baseline,
                                                       image=image,
                                                       alphas=alpha_batch)

    # 3. Compute gradients between model outputs and interpolated inputs.
    gradient_batch = compute_gradients(images=interpolated_path_input_batch,
                                       target_class_idx=target_class_idx)

    # Write batch indices and gradients to extend TensorArray.
    gradient_batches = gradient_batches.scatter(tf.range(from_, to), gradient_batch)    

  # Stack path gradients together row-wise into single tensor.
  total_gradients = gradient_batches.stack()

  # 4. Integral approximation through averaging gradients.
  avg_gradients = integral_approximation(gradients=total_gradients)

  # 5. Scale integrated gradients with respect to input.
  integrated_gradients = (image - baseline) * avg_gradients

  return integrated_gradients

# %%
ig_attributions = integrated_gradients(baseline=baseline_im,
                                       image=im_3,
                                       target_class_idx=0,
                                       m_steps=480)

# %%
def plot_img_attributions(baseline,
                          image,
                          target_class_idx,
                          m_steps=50,
                          cmap=None,
                          overlay_alpha=0.4):

  attributions = integrated_gradients(baseline=baseline,
                                      image=image,
                                      target_class_idx=target_class_idx,
                                      m_steps=m_steps)

  # Sum of the attributions across color channels for visualization.
  # The attribution mask shape is a grayscale image with height and width
  # equal to the original image.
  attribution_mask = tf.reduce_sum(tf.math.abs(attributions), axis=-1)

  fig, axs = plt.subplots(nrows=2, ncols=2, squeeze=False, figsize=(8, 8))

  axs[0, 0].set_title('Baseline image')
  axs[0, 0].imshow(baseline)
  axs[0, 0].axis('off')

  axs[0, 1].set_title('Original image')
  axs[0, 1].imshow(image)
  axs[0, 1].axis('off')

  axs[1, 0].set_title('Attribution mask')
  axs[1, 0].imshow(attribution_mask, cmap=cmap)
  axs[1, 0].axis('off')

  axs[1, 1].set_title('Overlay')
  axs[1, 1].imshow(attribution_mask, cmap=cmap)
  axs[1, 1].imshow(image, alpha=overlay_alpha)
  axs[1, 1].axis('off')

  plt.tight_layout()
  return fig

# %% [markdown]
# ### Visualizing the attributions
#
# The IG Explainability is tested using an image labeled as "Tumor".

# %%
_ = plot_img_attributions(image=im_3,
                          baseline=baseline_im,
                          target_class_idx=0,
                          m_steps=480,
                          cmap=plt.cm.hot,
                          overlay_alpha=0.4)

# %% [markdown]
# ##### Stroma

# %%
im_B = tf.keras.preprocessing.image.load_img("/content/02Stroma.tif")
im_B = tf.keras.preprocessing.image.img_to_array(im_B)
im_B = tf.cast(im_B, tf.float32) / 255.

# %%
ig_attributions = integrated_gradients(baseline=baseline_im,
                                       image=im_B,
                                       target_class_idx=1,
                                       m_steps=480)
_ = plot_img_attributions(image=im_B,
                          baseline=baseline_im,
                          target_class_idx=1,
                          m_steps=480,
                          cmap=plt.cm.hot,
                          overlay_alpha=0.2)

# %% [markdown]
# #### Complex

# %%
im_C = tf.keras.preprocessing.image.load_img("/content/03Complex.tif")
im_C = tf.keras.preprocessing.image.img_to_array(im_C)
im_C = tf.cast(im_C, tf.float32) / 255.

ig_attributions = integrated_gradients(baseline=baseline_im,
                                       image=im_C,
                                       target_class_idx=2,
                                       m_steps=480)
_ = plot_img_attributions(image=im_C,
                          baseline=baseline_im,
                          target_class_idx=2,
                          m_steps=480,
                          cmap=plt.cm.hot,
                          overlay_alpha=0.3)

# %% [markdown]
# #### Lympho

# %%
im_D = tf.keras.preprocessing.image.load_img("/content/04Lympho.tif")
im_D = tf.keras.preprocessing.image.img_to_array(im_D)
im_D = tf.cast(im_D, tf.float32) / 255.

ig_attributions = integrated_gradients(baseline=baseline_im,
                                       image=im_D,
                                       target_class_idx=3,
                                       m_steps=480)
_ = plot_img_attributions(image=im_D,
                          baseline=baseline_im,
                          target_class_idx=3,
                          m_steps=480,
                          cmap=plt.cm.hot,
                          overlay_alpha=0.3)

# %% [markdown]
# #### Debris

# %%
im_E = tf.keras.preprocessing.image.load_img("/content/05Debris.tif")
im_E = tf.keras.preprocessing.image.img_to_array(im_E)
im_E = tf.cast(im_E, tf.float32) / 255.

ig_attributions = integrated_gradients(baseline=baseline_im,
                                       image=im_E,
                                       target_class_idx=4,
                                       m_steps=480)
_ = plot_img_attributions(image=im_E,
                          baseline=baseline_im,
                          target_class_idx=4,
                          m_steps=480,
                          cmap=plt.cm.hot,
                          overlay_alpha=0.2)

# %%
im_F = tf.keras.preprocessing.image.load_img("/content/06Mucosa.tif")
im_F = tf.keras.preprocessing.image.img_to_array(im_F)
im_F = tf.cast(im_F, tf.float32) / 255.

ig_attributions = integrated_gradients(baseline=baseline_im,
                                       image=im_F,
                                       target_class_idx=5,
                                       m_steps=480)
_ = plot_img_attributions(image=im_F,
                          baseline=baseline_im,
                          target_class_idx=5,
                          m_steps=480,
                          cmap=plt.cm.hot,
                          overlay_alpha=0.3)

# %% [markdown]
# #### Adipose

# %%
im_G = tf.keras.preprocessing.image.load_img("/content/07Adipose.tif")
im_G = tf.keras.preprocessing.image.img_to_array(im_G)
im_G = tf.cast(im_G, tf.float32) / 255.

ig_attributions = integrated_gradients(baseline=baseline_im,
                                       image=im_G,
                                       target_class_idx=6,
                                       m_steps=480)
_ = plot_img_attributions(image=im_G,
                          baseline=baseline_im,
                          target_class_idx=6,
                          m_steps=480,
                          cmap=plt.cm.hot,
                          overlay_alpha=0.3)

# %% [markdown]
# In this way we can demonstrate classification of images for oncology applications.

# %% [markdown]
# ### **References**
# [1] https://www.rcpath.org/discover-pathology/news/fact-sheets/histopathology.html
#
# [2] https://www.nationaldiagnostics.com/taxonomy/articles/histology/histology-fundamentals
#
# [3] https://www.leicabiosystems.com/knowledge-pathway/an-introduction-to-routine-and-special-staining/
#
# [4] Kather, J. N., Zöllner, F. G., Bianconi, F., Melchers, S. M., Schad, L. R., Gaiser, T., Weis, C.-A. (2016). Collection of textures in colorectal cancer histology [Data set]. Zenodo. http://doi.org/10.5281/zenodo.53169
#
# [5] https://www.tensorflow.org/tutorials/interpretability/integrated_gradients
